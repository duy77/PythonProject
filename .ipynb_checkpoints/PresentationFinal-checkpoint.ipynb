# %% [markdown]
# # Group 15 : SuperHero
#                                         Find the "best" place to live in Pittsburgh
#
# To find the "best" neighborhood to live in Pittsburgh, it must combined many factors. therefore, our metrics are only relative and get closer to the point. To do that, we came up with some metrics like good school district, housing value, household income, less criminal, more entertainment compared to another neighborhood, air quality, parks or more green area is more than another place.
# But some metrics don’t have the data or hard to find the data in csv, tsv file in the range City of Pittsburgh. Ex: good school distric or school rate.
# therefore, we use the datasets housing value, household income,less criminal to support our goal.

# %% [markdown]
# # Duy
# to get closer our goal. I choose my datasets are housing value and household income of neighborhood in Pittsburgh
# my metrics to find top 5 of neighborhoods have the most expensive house value and the most household income in city of Pittsburgh.
# first, I write the code to read my datasets and and show 10 first rows and all columnsto know what my datasets look like, and then choose the columns of my datasets statisfies my conditions. here I chose 3 columns : Id, Neighborhood name, housing value from $1,000,000 and more, household income from $200,000 and more to counts top 5 neingborhoods have the most expensive housing value, the most household income and graph it.

# %%
# Housing Value
import pandas as pd

file_path = pd.read_csv("housingvalue.tsv", sep="\t")
file_path.head(10) # the same file_path.head(10)
# Out:
#    _id       Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0    1   Allegheny Center   1              38.0                19.000000
# 1    2     Allegheny West   2              77.0                34.000000
# 2    3          Allentown   3             575.0               124.004032
# 3    4          Arlington   4             469.0                93.866927
# 4    5  Arlington Heights   5               0.0                10.000000
# 5    6         Banksville   6             980.0               116.773285
# 6    7  Bedford Dwellings   7              51.0                37.000000
# 7    8          Beechview   8            2043.0               189.261724
# 8    9        Beltzhoover   9             543.0               126.198257
# 9   10         Bloomfield  10            1650.0               149.338542
#
#    Estimate; Total: - Less than $10,000  \
# 0                                   0.0
# 1                                   6.0
# ...

# %%
file_path.columns
# Out:
# Index(['_id', 'Neighborhood', 'Id', 'Estimate; Total:',
#        'Margin of Error; Total:', 'Estimate; Total: - Less than $10,000',
#        'Margin of Error; Total: - Less than $10,000',
#        'Estimate; Total: - $10,000 to $14,999',
#        'Margin of Error; Total: - $10,000 to $14,999',
#        'Estimate; Total: - $15,000 to $19,999',
#        'Margin of Error; Total: - $15,000 to $19,999',
#        'Estimate; Total: - $20,000 to $24,999',
#        'Margin of Error; Total: - $20,000 to $24,999',
#        'Estimate; Total: - $25,000 to $29,999',
#        'Margin of Error; Total: - $25,000 to $29,999',
#        'Estimate; Total: - $30,000 to $34,999',
#        'Margin of Error; Total: - $30,000 to $34,999',
#        'Estimate; Total: - $35,000 to $39,999',
#        'Margin of Error; Total: - $35,000 to $39,999',
#        'Estimate; Total: - $40,000 to $49,999',
#        'Margin of Error; Total: - $40,000 to $49,999',
#        'Estimate; Total: - $50,000 to $59,999',
# ...

# %%
import pandas as pd

# Load the TSV file into a DataFrame
file_path = 'housingvalue.tsv'  
data = pd.read_csv(file_path, sep='\t')  

# Select the columns representing ID, neighborhood, and prices of $1,000,000 or more
columns = ['Id', 'Neighborhood', 'Estimate; Total: - $1,000,000 or more']

# Find the 5 neighborhoods with the most expensive houses
top_5_neighborhoods = data.nlargest(5, 'Estimate; Total: - $1,000,000 or more')[columns]

# Print the top 5 neighborhoods with the respective count of houses
print("Top 5 neighborhoods with the most expensive houses:")
print(top_5_neighborhoods)
# Out:
# Top 5 neighborhoods with the most expensive houses:
#     Id         Neighborhood  Estimate; Total: - $1,000,000 or more
# 76  77  Squirrel Hill North                                  136.0
# 68  69            Shadyside                                   70.0
# 53  54     Mount Washington                                   27.0
# 77  78  Squirrel Hill South                                   27.0
# 5    6           Banksville                                   15.0

# %%
# Plot the data
import matplotlib.pyplot as plt

top_5_neighborhoods.plot.bar(x='Neighborhood', y='Estimate; Total: - $1,000,000 or more', rot=30)

plt.xlabel('Neighborhood')
plt.ylabel('Estimate Total Number')
plt.title('Top 5 Neighborhoods with Most Expensive Houses')
plt.show()

# %%
# Load the TSV file into a DataFrame
file_path = 'housingvalue.tsv'  
data = pd.read_csv(file_path, sep='\t')  

# Select the columns representing ID, neighborhood, and prices of $1,000,000 or more
columns = ['Id', 'Neighborhood', 'Estimate; Total: - $1,000,000 or more']

# Find the 5 neighborhoods with the most expensive houses
top_5 = data.nlargest(5, 'Estimate; Total: - $1,000,000 or more')[columns]

# Extract labels and sizes for the pie chart
labels = top_5['Neighborhood']
sizes = top_5['Estimate; Total: - $1,000,000 or more']

# Plotting the pie chart
plt.figure(figsize=(8, 8))  # Define the size of the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Neighborhoods with Most Expensive Houses')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
from PIL import Image
from IPython.display import display

img = Image.open('img/mansion.jpeg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F82CFDA9DC0>

# %%
# Household income
import pandas as pd

# %matplotlib inline
# load in the community center data file
data = pd.read_csv("householdincome.csv", index_col="Estimate; Total:", parse_dates=True)

# look at the first ten rows of the data
data.head(10)
# Out:
#                   _id       Neighborhood  Id  Margin of Error; Total:  \
# Estimate; Total:
# 870.0               1   Allegheny Center   1                93.000000
# 146.0               2     Allegheny West   2                36.000000
# 1069.0              3          Allentown   3               132.457540
# 701.0               4          Arlington   4               104.465305
# 144.0               5  Arlington Heights   5                59.000000
# 1946.0              6         Banksville   6               229.222599
# 723.0               7  Bedford Dwellings   7                53.000000
# 3567.0              8          Beechview   8               258.027130
# 848.0               9        Beltzhoover   9               156.057682
# 4571.0             10         Bloomfield  10               205.494525
#
#                   Estimate; Total: - Less than $10,000  \
# Estimate; Total:
# 870.0                                            147.0
# ...

# %%
file_path = 'householdincome.csv'

# Load the CSV file into a DataFrame
data = pd.read_csv(file_path)

# access the columns attribute
columns = data.columns
print(columns)
# Out:
# Index(['_id', 'Neighborhood', 'Id', 'Estimate; Total:',
#        'Margin of Error; Total:', 'Estimate; Total: - Less than $10,000',
#        'Margin of Error; Total: - Less than $10,000',
#        'Estimate; Total: - $10,000 to $14,999',
#        'Margin of Error; Total: - $10,000 to $14,999',
#        'Estimate; Total: - $15,000 to $19,999',
#        'Margin of Error; Total: - $15,000 to $19,999',
#        'Estimate; Total: - $20,000 to $24,999',
#        'Margin of Error; Total: - $20,000 to $24,999',
#        'Estimate; Total: - $25,000 to $29,999',
#        'Margin of Error; Total: - $25,000 to $29,999',
#        'Estimate; Total: - $30,000 to $34,999',
#        'Margin of Error; Total: - $30,000 to $34,999',
#        'Estimate; Total: - $35,000 to $39,999',
#        'Margin of Error; Total: - $35,000 to $39,999',
#        'Estimate; Total: - $40,000 to $44,999',
#        'Margin of Error; Total: - $40,000 to $44,999',
#        'Estimate; Total: - $45,000 to $49,999',
# ...

# %%
# Load the CSV file into a DataFrame
file_path = 'householdincome.csv'  
data = pd.read_csv(file_path)  

# Specify the correct column name for the income range
income_column = 'Estimate; Total: - $200,000 or more'

# Select the columns needed for analysis
columns = ['Id', 'Neighborhood', income_column]

# Find the 5 neighborhoods with the highest number of households in the income range $200,000 or more
top_5_neighborhoods = data.nlargest(5, income_column)[columns]

# Print the top 5 neighborhoods with the respective count of households
print("Top 5 neighborhoods with the most households earning $200,000 or more':")
print(top_5_neighborhoods)
# Out:
# Top 5 neighborhoods with the most households earning $200,000 or more':
#     Id               Neighborhood  Estimate; Total: - $200,000 or more
# 76  77        Squirrel Hill North                                935.0
# 77  78        Squirrel Hill South                                821.0
# 68  69                  Shadyside                                559.0
# 63  64               Point Breeze                                482.0
# 16  17  Central Business District                                364.0

# %%
# Plot the data
import matplotlib.pyplot as plt

top_5_neighborhoods.plot.bar(x='Neighborhood', y='Estimate; Total: - $200,000 or more', rot=30)

plt.xlabel('Neighborhood')
plt.ylabel('Estimate Total Number')
plt.title('Top 5 Neighborhoods with the most households earning $200,000 or more')
plt.show()

# %%
# Load the CSV file into a DataFrame
file_path = 'householdincome.csv'  
data = pd.read_csv(file_path) 

# Specify the correct column name for the income range
income_column = 'Estimate; Total: - $200,000 or more'

# Select the columns needed for analysis
columns = ['Id', 'Neighborhood', income_column]

# Find the 5 neighborhoods with the most expensive houses
top_5 = data.nlargest(5,'Estimate; Total: - $200,000 or more' )[columns]

# Extract labels and sizes for the pie chart
labels = top_5['Neighborhood']
sizes = top_5['Estimate; Total: - $200,000 or more']

# Plotting the pie chart
plt.figure(figsize=(8, 8))  # Define the size of the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Neighborhoods with the most households earning $200,000 or more')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
from PIL import Image
from IPython.display import display

img = Image.open('img/images.jpeg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=276x183 at 0x7F82CDD5E700>

# %%
# Duy 
conclusion: the result shows Squirrel Hill North has household income $200,000 and more is 935 and house value 1,000,000 and more is 136 
both of them are top of 5 Neighborhoods. therefore, my conclusion is squirrel hill North is the best place to live.

# %% [markdown]
# <h1>Khristian</h1>
#
#
# When analyzing crime data, we wanted to really focus on violent crime as our point of reference, as this is usually an indicator of the overall safety of a certain area. I wanted to make sure the data was presented in a way that would make sense but also provide scale. My approach was that we will simply organize the data into neighborhoods, and track crime via crime codes, as the column titled "OFFENSES" provides a crime code directly first in every crime, so this allowed me to organize everything in a much more readable manner. Firstly, let's start with grand totals.

# %%
#code
import pandas as pd
import matplotlib.pyplot as plt

#load file
crimeData = pd.read_csv('crimeBlots.tsv', sep='\t')

#crime data array which holds everything in the offenses column
crimeData['CRIME'] = crimeData['OFFENSES']

#compare against incidentneighborhood.size() (the total neighborhoods)
totalCrime = crimeData.groupby('INCIDENTNEIGHBORHOOD').size()

#
totalCrime = totalCrime.sort_values(ascending=False)

#use a bar graph to plot data
plt.figure(figsize=(14, 8))
plt.bar(totalCrime.index, totalCrime.values, color='r')
plt.xlabel('Neighborhoods')
plt.ylabel('Crimes')
plt.title('Total Crimes by Neighborhood')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As we can see here, from a simple total of crime assessment, we can see that the Golden Triangle has the most crime incidents, followed by Bloomfield and the South Side. I think one thing to consider here is that not every area can be uniformly understood based on this graph, since south side is the club and bar district, it somewhat makes sense that a disproportionate amount of crime is reported there, the neighborhood is likely quite safe outside of a rowdy Saturday night.
#
# Let's look at the top 5 of each

# %%
import pandas as pd

crimeCounts = sorted_total_crimes.reset_index()
crimeCounts.columns = ['Neighborhood', 'Total Crimes']

# Display the top 5 and bottom 5 neighborhoods
print("Top 5 Neighborhoods with Most Crimes:")
print(crimeCounts.head(5))

print("\nBottom 5 Neighborhoods with Least Crimes:")
print(crimeCounts.tail(5))
# Out:
# Top 5 Neighborhoods with Most Crimes:
#                   Neighborhood  Total Crimes
# 0  Golden Triangle/Civic Arena          3524
# 1                   Bloomfield          2811
# 2             South Side Flats          2720
# 3               Homewood South          2187
# 4              Central Oakland          1891
#
# Bottom 5 Neighborhoods with Least Crimes:
#        Neighborhood  Total Crimes
# 70    Spring Garden             1
# 71         Sheraden             1
# 72   East Allegheny             1
# 73          Elliott             1
# 74  Crafton Heights             1

# %% [markdown]
# So as we can see here, if we excuse the golden triangle and south side for being the busiest areas of the city, then we can assert Bloomfield, Homewood South, and Oakland as the least safe residential areas, while Spring Garden, Sheraden, East Allegheny, Elliot, and Crafton Heights, were all tied with only one misdemeanor or above crime.
#
# I find this interesting because as a resident of Oakland I have never felt unsafe! But I think just like South Side, when it comes to busy areas with bars and young people, it creates a disproportionate representation of the data since much of the crime is clustered within only a few days of a few hours per week.
#
# However, that data is simply not good enough to make any conclusions so let's associate this data with home values to get a better grasp.

# %%
import pandas as pd
import matplotlib.pyplot as plt

#load files
crimeData = pd.read_csv('crimeBlots.tsv', sep='\t')
housingData = pd.read_csv('housingvalue.tsv', sep='\t')

#count all crimes by neighborhood
totalCrime = crimeData.groupby('INCIDENTNEIGHBORHOOD').size().reset_index(name='Total Crimes')

#*ahem*
#we merge the data, we wanted out the neighborhood, the totals of housing 1m or more, and then we wanted the crime data and incidentneighborhood from the crimeBlots
crimeHousingMerge = pd.merge(totalCrime, housingData[['Neighborhood', 'Estimate; Total: - $1,000,000 or more']], left_on='INCIDENTNEIGHBORHOOD', right_on='Neighborhood', how='inner')

#we create a safety index which acts as a ratio in correlation to housing values and crime
crimeHousingMerge['Safety Index'] = (crimeHousingMerge['Estimate; Total: - $1,000,000 or more'] / crimeHousingMerge['Estimate; Total: - $1,000,000 or more'].max()) / (crimeHousingMerge['Total Crimes'] / crimeHousingMerge['Total Crimes'].max())

#sort by the safety index
neighborhoodsBySafetyIndex = crimeHousingMerge.sort_values(by='Safety Index', ascending=False)

#head() the top 5 by safety index
topBySafetyIndex = neighborhoodsBySafetyIndex.head(5)

#present data using a scatter graph
plt.figure(figsize=(10, 6))
plt.scatter(crimeHousingMerge['Total Crimes'], crimeHousingMerge['Estimate; Total: - $1,000,000 or more'], c=crimeHousingMerge['Safety Index'], cmap='viridis')
plt.colorbar(label='Safety/Value Index')
plt.xlabel('Total Crimes')
plt.ylabel('Homes Valued Over $1M')
plt.title('Neighborhood Safety vs. High-Value Homes')
plt.grid(True)
plt.show()

#display top 5
print(topBySafetyIndex[['Neighborhood', 'Total Crimes', 'Estimate; Total: - $1,000,000 or more', 'Safety Index']])
# Out:
#            Neighborhood  Total Crimes  Estimate; Total: - $1,000,000 or more  \
# 18       East Allegheny             1                                    7.0
# 21         East Liberty             3                                   10.0
# 42     Mount Washington           179                                   27.0
# 58  Squirrel Hill North          1110                                  136.0
# 54            Shadyside          1419                                   70.0
#
#     Safety Index
# 18    144.683824
# 21     68.897059
# 42      3.117688
# 58      2.532432
# 54      1.019618

# %% [markdown]
# So as we can see here, the lowest crime rate does not always mean the highest value neighborhood. We notice the East Liberty has a very high safety to value index, and that Squirrel Hill despite having 1110 crimes reported, still maintains a safety index that is over 1. We measured the safety index simply my saying
#
# ValueIndex = (num homes valued over $1m / the max(homes valued over 1m)) /divided by/ (total crimes / max(total crimes))
#
# So essentially, most neighborhoods would fall under 1, and only the most notable areas would be able to keep above 1, so with that being said, we notice we highlighted some very special neighborhoods in the area. East Liberty being the recent urban development expansion area, Mount Washington is known for it's great views of the valley and the city, and as observed, Squirrel Hill is known for it's large homes and high income residents while surrounded by the urban core of Pittsburgh.
#
# So with this, we can say the most high value areas, with the best crime tradeoff, is East Liberty, and then Mt Washington. With notable mentions of Sq Hill and Shadyside

# %% [markdown]
# However let's return to some of Duy's data to make our final assesment

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('householdincome.csv')

# Specify the correct column name for the income range
incomeCol = 'Estimate; Total: - $200,000 or more'

# Select the columns needed for analysis
cols = ['Id', 'Neighborhood', incomeCol]

top = data.nlargest(7, incomeCol)[cols]
top.plot.bar(x='Neighborhood', y='Estimate; Total: - $200,000 or more', rot=30)

plt.xlabel('Neighborhood')
plt.ylabel('Estimate Total Number')
plt.title('Top 5 Neighborhoods with the most households earning $200,000 or more')
plt.show()

# %% [markdown]
# So finally, after considering all of the crime stats, and housing values. We can now assess a bit more about safety in various neighborhoods. Harking back to the income data, we can see the Squirrel Hill is once again on top, unsurprisingly since the area has the most houses over $1m, but it definitely goes to show that the crime data should not be observed alone! If we were soley using crime data, you would think areas like downtown are unlivable, but we can see here that there are quite a few high income individuals who reside downtown as well, goes to show it is not all bad!
#
# The conclusion from my data also agrees with Duy's assesment, Squirrel Hill is the best place to live in Pittsburgh, with maybe an argument for areas like Shadyside as well considering how high it scored on the safety to crime index.

# %% [markdown]
# # Ekko

# %% [markdown]
# The data I chose is employment, and my indicator is to find the communities with the highest number of employees. I used the census method to compile the first ten rows of data to count them. Then I will find out what the communities with the highest employment population and the occupations with the highest employment are, and in which communities they are distributed.

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("employment.csv")

# Display the first 10 rows and ensure we have 35 columns
df.head(10)
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
# 5         Banksville         5             4,144
# 6  Bedford Dwellings        15             1,202
# 7          Beechview         5             7,974
# 8        Beltzhoover         6             1,925
# 9         Bloomfield        12             8,442
#
#   Total Age 16+ N'hood Residents Employed (2010 Est.)  \
# 0                                                386
# 1                                                151
# 2                                                858
# 3                                                685
# 4                                                 72
# 5                                              2,532
# ...

# %% [markdown]
# We can clearly see the employment population information and the employment probability of each occupation.

# %%
import pandas as pd


df_subset = df.iloc[:10]

# Define employment_columns: This should be a list of columns in df_subset that represent different occupations
# For example:
employment_columns = [col for col in df.columns if col.startswith('Resident Jobs:')]

# Calculate the mean employment rate for each occupation in the subset
mean_employment_rates = df_subset[employment_columns].apply(lambda x: x.str.rstrip('%').astype(float)).mean()

# Sorting the mean employment rates
sorted_employment_rates = mean_employment_rates.sort_values()

# Extracting the highest, middle, and lowest employment rate occupations
occupation_highest_employment_subset = sorted_employment_rates.idxmax()
highest_rate = sorted_employment_rates.max()

# Middle occupation might need a more nuanced approach depending on the number of occupations
if len(sorted_employment_rates) % 2 == 0:  # Even number of elements
    middle_index1 = len(sorted_employment_rates) // 2 - 1
    middle_index2 = len(sorted_employment_rates) // 2
    occupation_middle_employment_subset = sorted_employment_rates.iloc[[middle_index1, middle_index2]].index.tolist()
    middle_rate = sorted_employment_rates.iloc[[middle_index1, middle_index2]].mean()
else:  # Odd number of elements
    middle_index = len(sorted_employment_rates) // 2
    occupation_middle_employment_subset = sorted_employment_rates.index[middle_index]
    middle_rate = sorted_employment_rates.iloc[middle_index]

occupation_lowest_employment_subset = sorted_employment_rates.idxmin()
lowest_rate = sorted_employment_rates.min()

# Display results
occupation_highest_employment_subset, highest_rate, occupation_middle_employment_subset, middle_rate, occupation_lowest_employment_subset, lowest_rate
# Out:
# ('Resident Jobs: Educ, health and social svc',
#  30.009999999999998,
#  'Resident Jobs: Prof, scientific, admin, and waste mgmt',
#  8.2,
#  'Resident Jobs: Information',
#  2.3)

# %% [markdown]
# These data first let us know the occupations with the highest, medium and lowest employment probability.

# %%
import pandas as pd

# Load your data
df = pd.read_csv('employment.csv')

# Prepare the data: Convert necessary columns
df['Population (2010)'] = df['Population (2010)'].str.replace(',', '').astype(int)
df_first_10 = df.iloc[:10].copy()

# Convert job categories from percentage to absolute numbers
job_categories = [col for col in df_first_10.columns if 'Resident Jobs:' in col]
for category in job_categories:
    df_first_10[category] = df_first_10[category].str.rstrip('%').astype(float) / 100 * df_first_10['Population (2010)']

# Find the job category with the highest total employment
total_employment_by_category = df_first_10[job_categories].sum(axis=0)
highest_employment_category = total_employment_by_category.idxmax()

# Identify the neighborhood with the highest employment in that category
highest_employment_in_category_value = df_first_10[highest_employment_category].max()
target_neighborhood_index = df_first_10[df_first_10[highest_employment_category] == highest_employment_in_category_value].index[0]
target_neighborhood_name = df_first_10.loc[target_neighborhood_index, 'Neighborhood']
target_neighborhood_employment_rate = highest_employment_in_category_value / df_first_10.loc[target_neighborhood_index, 'Population (2010)']

# Calculate the same for the four surrounding neighborhoods
# Safely select two neighborhoods before and after the target, handling edges of the DataFrame
start_index = max(target_neighborhood_index - 2, 0)
end_index = min(target_neighborhood_index + 3, len(df_first_10))
surrounding_neighborhoods = df_first_10.iloc[start_index:end_index].copy()
surrounding_neighborhoods_excluding_target = surrounding_neighborhoods[surrounding_neighborhoods.Neighborhood != target_neighborhood_name]

# Display the results
print(f"Top Employment Category: {highest_employment_category}")
print(f"Neighborhood with Highest Employment in this Category: {target_neighborhood_name} with an employment rate of {target_neighborhood_employment_rate:.2%}")
print("\nSurrounding Neighborhoods' Employment in this Category:")
for idx, row in surrounding_neighborhoods_excluding_target.iterrows():
    neighborhood_name = row['Neighborhood']
    population = row['Population (2010)']
    employment_in_category = row[highest_employment_category]
    employment_rate_in_category = employment_in_category / population
    print(f"{neighborhood_name}: Employment Rate: {employment_rate_in_category:.2%}")

# %% [markdown]
# Through this, we can know which community has the highest employment occupation population and its employment probability. It is Bloomfield, and we can also know that its Educ, health and social SVC is much more developed than other communities.

# %%
import matplotlib.pyplot as plt

# Select the last five neighborhoods from the first 10 rows
last_five_neighborhoods = df_first_10.iloc[-5:]

# Plotting the bar chart for the last five neighborhoods
plt.figure(figsize=(10, 6))
plt.bar(last_five_neighborhoods['Neighborhood'], last_five_neighborhoods['Total Age 16+ N\'hood Residents Employed (2010 Est.)'], color='lightgreen')
plt.xlabel('Neighborhood')
plt.ylabel('Total Employed Residents')
plt.title('Employment Population of the Last Five Neighborhoods in the First 10 Rows')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# I used a bar chart to show the five communities with the largest employment population. It is obvious that Bloomfield has the most.

# %% [markdown]
# Conclusion：
# After comparing multiple sets of data, it is concluded that Bloomfield is the best community, and its educational resources are also very sufficient compared to other communities, which they cannot compare with.
